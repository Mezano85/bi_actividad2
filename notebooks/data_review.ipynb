# %%
import pandas as pd
import json

# %% [markdown]
# ## Inspección del formato de datos - Libraries.js -

# %%
df_libraries = pd.read_json('../data/Libraries.json', lines=True)
df_libraries.head(n=5)
# Out:
#    _id                              title        isbn  pageCount  \
# 0    1                  Unlocking Android  1933988673        416
# 1    2  Android in Action, Second Edition  1935182722        592
# 2    3           Specification by Example  1617290084          0
# 3    4                   Flex 3 in Action  1933988746        576
# 4    5                   Flex 4 in Action  1935182420        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
# Tamaño de los datos (filas , columnas)
df_libraries.shape
# Out:
# (399, 11)

# %% [markdown]
# ## Inspección del formato de datos - Licencias Locales CSV -

# %%
df_licencias = pd.read_csv('../data/Licencias_Locales_202104.csv', sep=";", encoding='UTF-8')
df_licencias.head(n=5)
# Out:
#    id_local  id_distrito_local   desc_distrito_local  id_barrio_local  \
# 0  10003584                  1  CENTRO                            103
# 1  10003585                  1  CENTRO                            103
# 2  10003585                  1  CENTRO                            103
# 3  10003585                  1  CENTRO                            103
# 4  10003587                  1  CENTRO                            104
#
#       desc_barrio_local  cod_barrio_local  id_seccion_censal_local  \
# 0  CORTES                               3                     1067
# 1  CORTES                               3                     1067
# 2  CORTES                               3                     1067
# 3  CORTES                               3                     1067
# 4  JUSTICIA                             4                     1082
#
#    desc_seccion_censal_local coordenada_x_local coordenada_y_local  ...  \
# ...

# %%
# Tamaño de los datos (filas , columnas)
df_licencias.shape
# Out:
# (132171, 46)

# %% [markdown]
# ## Inspección del formato de datos - Locales CSV -

# %%
df_locales = pd.read_csv('../data/Locales_202104.csv', sep=";", encoding='ISO-8859-1')
df_locales.head(n=5)
# Out:
#     id_local  id_distrito_local   desc_distrito_local  id_barrio_local  \
# 0  280046845                  8  FUENCARRAL-EL PARDO               803
# 1  280046855                  8  FUENCARRAL-EL PARDO               803
# 2  280046865                  8  FUENCARRAL-EL PARDO               803
# 3  280046871                  8  FUENCARRAL-EL PARDO               803
# 4  280046888                  8  FUENCARRAL-EL PARDO               803
#
#       desc_barrio_local  cod_barrio_local  id_seccion_censal_local  \
# 0  PEÑA GRANDE                        NaN                      NaN
# 1  PEÑA GRANDE                        NaN                      NaN
# 2  PEÑA GRANDE                        NaN                      NaN
# 3  PEÑA GRANDE                        NaN                      NaN
# 4  PEÑA GRANDE                        NaN                      NaN
#
#    desc_seccion_censal_local coordenada_x_local coordenada_y_local  ...  \
# ...

# %%
# Tamaño de los datos (filas , columnas)
df_locales.shape
# Out:
# (148216, 40)

# %% [markdown]
# ## Inspección del formato de datos - Locales CSV -

# %%
df_terrazas = pd.read_csv('../data/Terrazas_202104.csv', sep=";", encoding='ISO-8859-1')
df_terrazas.head(n=5)
# Out:
#    id_terraza   id_local  id_distrito_local   desc_distrito_local  \
# 0           7  280067128                 20  SAN BLAS-CANILLEJAS
# 1          33  270403150                  4  SALAMANCA
# 2          34  270078567                  4  SALAMANCA
# 3          36   40002021                  4  SALAMANCA
# 4          40   40002808                  4  SALAMANCA
#
#    id_barrio_local     desc_barrio_local  id_ndp_edificio  \
# 0             2005  ROSAS                        20157611
# 1              404  GUINDALERA                   11018870
# 2              404  GUINDALERA                   11018555
# 3              404  GUINDALERA                   11018545
# 4              401  RECOLETOS                    11014033
#
#    id_clase_ndp_edificio  id_vial_edificio       clase_vial_edificio  ...  \
# 0                      1              2443  CALLE                     ...
# 1                      1             42500  AVENIDA                   ...
# ...

# %%
# Tamaño de los datos (filas , columnas)
df_terrazas.shape
# Out:
# (6275, 57)
